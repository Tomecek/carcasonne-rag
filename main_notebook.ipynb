# %%
from vector.create_indexes import loading_documents
import tqdm
from pathlib import Path

DATA_DIRECTORY = Path("data")

documents = loading_documents(DATA_DIRECTORY)
# Out:
# [00:07<00:00] 12/? | |            1.58it/s

# %%
documents
# Out:
# [Document(metadata={'producer': 'Adobe PDF Library 10.0.1', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2025-04-15T12:14:32+02:00', 'moddate': '2025-04-15T12:15:18+02:00', 'trapped': '/False', 'source': 'data\\Carcassonne-1-pravidla-2025-CZ-web.pdf', 'total_pages': 4, 'page': 0, 'page_label': '1'}, page_content='6 velkých družiníků 8 družiníků a 1 opat 6 bodových kartiček\n2× katedrála \n 7× hostinec \n 1× řeka \ns\xa0hostincem\n1\nV tomto rozšíření budete vylepšovat cesty útulnými  \nhostinci a města velkolepými katedrálami, které vám'),
# ...

# %%
for item in documents:
    print(len(item.page_content))
# Out:
# 217
# 217
# 249
# 220
# 252
# 48
# 244
# 241
# 246
# 221
# 211
# 236
# 245
# 246
# 54
# 238
# 200
# 228
# 230
# 248
# 174
# 239
# 251
# 253
# 253
# 245
# 34
# 181
# 199
# 251
# 221
# 236
# 253
# 218
# 240
# 196
# 242
# 231
# 237
# 183
# 248
# 197
# 221
# 210
# 231
# 249
# 76
# 244
# 208
# 229
# 227
# 244
# 254
# 192
# 238
# 229
# 204
# 253
# 248
# 152
# 236
# 242
# 205
# 241
# 173
# 191
# 206
# 227
# 234
# 204
# 238
# 233
# 229
# 247
# 241
# 254
# 175
# 238
# 215
# 246
# 247
# 231
# 47
# 244
# 225
# 226
# 222
# 242
# 215
# 46
# 241
# 226
# 198
# 246
# 251
# 117
# 175
# 213
# 248
# 238
# 236
# 249
# 174
# 195
# 245
# 207
# 223
# 251
# 108
# 177
# 183
# 220
# 244
# 231
# 245
# 255
# 247
# 182
# 227
# 79
# 20
# 256
# 237
# 217
# 253
# 225
# 223
# 240
# 248
# 240
# 125
# 143
# 241
# 225
# 230
# 174
# 240
# 201
# 248
# 213
# 230
# 224
# 172
# 231
# 253
# 219
# 242
# 217
# 204
# 204
# 245
# 241
# 233
# 240
# 250
# 234
# 239
# 182
# 170
# 208
# 245
# 198
# 217
# 183
# 207
# 222
# 255
# 19
# ...
